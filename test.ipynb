# %% [markdown]
# # Check Q table

# %%
import numpy as np

path = "output/p2p/thread0/episode10/q_table/battery_buy_qtb_0.npy"
q_table = np.load(path)
print(q_table[:, :, 2])
# Out:
# [[ 997.87963542  997.88151447  998.90257601 ... 1000.
#   1000.         1000.        ]
#  [ 998.84566944  998.92261773  998.91388587 ... 1000.
#   1000.         1000.        ]
#  [ 998.90215098  998.8296318   998.93730867 ... 1000.
#   1000.         1000.        ]
#  ...
#  [ 998.91370457  997.93588053  998.91370457 ... 1000.
#   1000.         1000.        ]
#  [1000.         1000.         1000.         ... 1000.
#   1000.         1000.        ]
#  [1000.         1000.         1000.         ... 1000.
#   1000.         1000.        ]]
